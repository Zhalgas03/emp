# %%
import os
import shutil
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import sklearn
from sklearn.metrics import classification_report
from keras.applications import *
from keras.layers import *
from keras.models import Model, load_model
from keras.optimizers import Adam, AdamW
from sklearn.utils import class_weight
from tqdm import tqdm
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.efficientnet_v2 import preprocess_input as base_preprocess
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, RocCurveDisplay, auc
from sklearn.utils.multiclass import unique_labels
from collections import Counter
from pathlib import Path
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from PIL import Image
from sklearn.preprocessing import LabelEncoder
from sklearn.utils.class_weight import compute_class_weight
import itertools

# %% [markdown]
# **Load data**

# %%
import os
import sys
import cv2
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

# === 1. Paths ===
base_dir = r"C:\Users\falco\Desktop\emp\BTDataset"
base_dir = os.path.normpath(base_dir)

train_dir = os.path.join(base_dir, "Training")

print("base_dir:", repr(base_dir))
print("train_dir exists:", os.path.exists(train_dir))
print("-" * 40)

# === 2. Data loading and preprocessing ===
images = []
labels = []
bad_reads = 0

# ✅ Only load images from the Training folder
folder_path = train_dir
if not os.path.exists(folder_path):
    print(f"❌ Training folder not found: {folder_path}")
    sys.exit(1)

# Loop through each class folder (glioma, meningioma, etc.)
for class_name in os.listdir(folder_path):
    class_path = os.path.join(folder_path, class_name)
    if not os.path.isdir(class_path):
        continue
    
    # Iterate through all image files inside the class folder
    for fname in os.listdir(class_path):
        if not (fname.lower().endswith(".jpg") or fname.lower().endswith(".png")):
            continue
        
        fpath = os.path.join(class_path, fname)
        img = cv2.imread(fpath)
        if img is None:
            bad_reads += 1
            continue
        
        # Convert BGR to RGB and resize to 224x224
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (224, 224))
        
        images.append(img)
        labels.append(class_name)

print("Total images loaded:", len(images))
print("Bad reads:", bad_reads)

if len(images) == 0:
    print("❌ No images found — exiting.")
    sys.exit(1)

# === 3. Convert to NumPy arrays ===
images = np.array(images, dtype=np.uint8)
labels = np.array(labels, dtype=str)

print("Images shape:", images.shape)
print("Labels shape:", labels.shape)
print("Unique classes:", np.unique(labels))

# === 4. Label encoding and one-hot conversion ===
le = LabelEncoder()
labels_encoded = le.fit_transform(labels)
labels_onehot = to_categorical(labels_encoded)

print("Classes and indices:", list(zip(le.classes_, range(len(le.classes_)))))
print("One-hot labels shape:", labels_onehot.shape)

# === 5. Save .npy files ===
data_path = os.path.join(base_dir, "data.npy")
labels_path = os.path.join(base_dir, "labels.npy")

try:
    np.save(data_path, images, allow_pickle=False)
    np.save(labels_path, labels_onehot, allow_pickle=False)
except Exception as e:
    print("❌ Error while saving:", e)
    sys.exit(1)

print("✅ Saved successfully:")
print(" -", data_path)
print(" -", labels_path)
# Out:
# base_dir: 'C:\\Users\\falco\\Desktop\\emp\\BTDataset'
# train_dir exists: True
# ----------------------------------------
# Total images loaded: 5712
# Bad reads: 0
# Images shape: (5712, 224, 224, 3)
# Labels shape: (5712,)
# Unique classes: ['glioma' 'meningioma' 'notumor' 'pituitary']
# Classes and indices: [('glioma', 0), ('meningioma', 1), ('notumor', 2), ('pituitary', 3)]
# One-hot labels shape: (5712, 4)
# ✅ Saved successfully:
#  - C:\Users\falco\Desktop\emp\BTDataset\data.npy
#  - C:\Users\falco\Desktop\emp\BTDataset\labels.npy

# %%
# === 6. Verification (load and check shapes) ===
data = np.load(data_path, mmap_mode='r')
labels = np.load(labels_path, mmap_mode='r')

print("Data shape:", data.shape)
print("Labels shape:", labels.shape)
# Out:
# Data shape: (5712, 224, 224, 3)
# Labels shape: (5712, 4)

# %% [markdown]
# Loading Images from the data

# %%
# Get unique one-hot class labels
unique_classes = np.unique(labels, axis=0)

# Create a dictionary to store one image sample per class
class_samples = {}

# Map class indices to their names (from LabelEncoder)
class_names = {0: "glioma", 1: "meningioma", 2: "notumor", 3: "pituitary"}

for class_label in unique_classes:
    class_indices = np.where(np.all(labels == class_label, axis=1))[0]
    random_index = np.random.choice(class_indices)  # 🔹 choose random sample
    class_samples[tuple(class_label)] = data[random_index]

# Plot one example per class
plt.figure(figsize=(8, 4))
for i, (class_label, image_data) in enumerate(class_samples.items()):
    class_index = np.argmax(class_label)   # find class index from one-hot
    class_name = class_names[class_index]  # map to name
    plt.subplot(1, 4, i + 1)
    plt.imshow(image_data)
    plt.title(f'{class_name}')
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# Frequency of the data

# %%
# Sum the one-hot encoded labels along the rows to get the frequency of each class
class_counts = np.sum(labels, axis=0)

# Map class indices to their corresponding names
class_names = {0: "glioma", 1: "meningioma", 2: "notumor", 3: "pituitary"}

# Plot the class frequencies
plt.figure(figsize=(5, 4))
plt.bar([class_names[class_idx] for class_idx in range(len(class_names))], class_counts)
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.title('Images in each class')

# Annotate the bars with the class frequencies (integer format)
for i, count in enumerate(class_counts):
    plt.text(i, count, str(int(count)), ha='center', va='bottom')

plt.show()

# %% [markdown]
# Split data

# %%
# Split the data into train, test, and validation sets
train_data, test_data, train_labels, test_labels = train_test_split(data, labels, test_size=0.1,stratify=labels, random_state=42)
train_data, val_data, train_labels, val_labels = train_test_split(train_data, train_labels, test_size=0.1,stratify=train_labels, random_state=42)

# %% [markdown]
# Split Data Frequecy

# %%
print("train_data shape:", train_data.shape)
print("train_labels shape:", train_labels.shape)
print("val_data shape:", val_data.shape)
print("val_labels shape:", val_labels.shape)
print("test_data shape:", test_data.shape)
print("test_labels shape:", test_labels.shape)
# Out:
# train_data shape: (4626, 224, 224, 3)
# train_labels shape: (4626, 4)
# val_data shape: (514, 224, 224, 3)
# val_labels shape: (514, 4)
# test_data shape: (572, 224, 224, 3)
# test_labels shape: (572, 4)

# %% [markdown]
# Data Frequency of Each Class

# %%
# Class name mapping for MRI dataset
class_names_mapping = {
    0: "glioma",
    1: "meningioma",
    2: "notumor",
    3: "pituitary"
}

# Calculate class distribution in each set
num_classes = train_labels.shape[1]
class_counts_train = np.sum(train_labels, axis=0)
class_counts_val = np.sum(val_labels, axis=0)
class_counts_test = np.sum(test_labels, axis=0)

# Store counts for each class
class_counts_mapping = {}
for index, class_name in class_names_mapping.items():
    class_counts_mapping[class_name] = {'Train': class_counts_train[index]}

for index, class_name in class_names_mapping.items():
    class_counts_mapping[class_name]['Validation'] = class_counts_val[index]

for index, class_name in class_names_mapping.items():
    class_counts_mapping[class_name]['Test'] = class_counts_test[index]

# Print class distribution mapping
for class_name, counts in class_counts_mapping.items():
    print(class_name)
    for set_name, count in counts.items():
        print(f" - {set_name}: {int(count)}")
# Out:
# glioma
#  - Train: 1070
#  - Validation: 119
#  - Test: 132
# meningioma
#  - Train: 1085
#  - Validation: 120
#  - Test: 134
# notumor
#  - Train: 1291
#  - Validation: 144
#  - Test: 160
# pituitary
#  - Train: 1180
#  - Validation: 131
#  - Test: 146

# %%
# Create pie charts for each set
for set_name in ['Train']:
    class_counts = [counts[set_name] for counts in class_counts_mapping.values()]
    class_labels = list(class_counts_mapping.keys())

    plt.figure(figsize=(5, 5))
    plt.pie(class_counts, labels=class_labels, startangle=140, autopct=lambda p: '{:.0f}'.format(p * sum(class_counts) / 100))
    plt.title(f'Class Distribution in {set_name} Set')
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.show()

# %%
# Create pie charts for each set
for set_name in ['Validation']:
    class_counts = [counts[set_name] for counts in class_counts_mapping.values()]
    class_labels = list(class_counts_mapping.keys())

    plt.figure(figsize=(5, 5))
    plt.pie(class_counts, labels=class_labels, startangle=140, autopct=lambda p: '{:.0f}'.format(p * sum(class_counts) / 100))
    plt.title(f'Class Distribution in {set_name} Set')
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.show()

# %%
# Create pie charts for each set
for set_name in ['Test']:
    class_counts = [counts[set_name] for counts in class_counts_mapping.values()]
    class_labels = list(class_counts_mapping.keys())

    plt.figure(figsize=(5, 5))
    plt.pie(class_counts, labels=class_labels, startangle=140, autopct=lambda p: '{:.0f}'.format(p * sum(class_counts) / 100))
    plt.title(f'Class Distribution in {set_name} Set')
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.show()

# %% [markdown]
# Augmentation

# %%
datagen = ImageDataGenerator(
    rotation_range=25,          # Increased (was 20) – better rotational robustness
    width_shift_range=0.15,     # Reduced (was 0.2) – avoids excessive horizontal shifting of lesion
    height_shift_range=0.15,    # Reduced (was 0.2) – prevents tumor area misalignment
    shear_range=0.15,           # Softer shear (was 0.2) – less geometric distortion
    zoom_range=0.25,            # Increased (was 0.2) – more variability in lesion scaling
    brightness_range=[0.8, 1.2],# simulates different MRI lighting and scanner exposure
    horizontal_flip=True,       
    fill_mode='nearest',        # preserves edge pixels instead of filling with black
    rescale=1./255              # normalizes pixel values to [0,1], improves convergence
)

val_datagen = ImageDataGenerator(rescale=1./255)

# %%
batch = next(datagen.flow(train_data, train_labels, batch_size=4))
imgs = batch[0]
plt.figure(figsize=(8,2))
for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(imgs[i])
    plt.axis('off')
plt.show()

# %% [markdown]
# Callbacks

# %%
lr_reduce = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=3,            # was 5 — reacts slightly faster to plateau
    mode='max',
    min_lr=1e-6,           # was 1e-4 — allows finer learning rate reduction
    verbose=1
)

save_dir = r"C:\Users\falco\Desktop\emp\SavedModels"
os.makedirs(save_dir, exist_ok=True)
saved_model = os.path.join(save_dir, "EfficientNetV2S_CBAM.h5")

model_chkpt = ModelCheckpoint(saved_model ,save_best_only = True, monitor = 'val_accuracy',verbose = 1)

early_stop = EarlyStopping(
    monitor='val_accuracy',
    patience=7,           # prevents overfitting, restores best weights
    restore_best_weights=True,
    mode='max',
    verbose=1
)


callback_list = [model_chkpt, lr_reduce, early_stop]

# %% [markdown]
# CBAM

# %%
def cbam_block(x, ratio=8):
    ch = x.shape[-1]
    
    avg_pool = GlobalAveragePooling2D()(x)
    max_pool = GlobalMaxPooling2D()(x)
    shared_dense = Dense(ch // ratio, activation='relu', use_bias=False)
    dense_out = Dense(ch, activation='sigmoid', use_bias=False)

    avg_out = dense_out(shared_dense(avg_pool))
    max_out = dense_out(shared_dense(max_pool))
    ch_att = Add()([avg_out, max_out])
    ch_att = tf.reshape(ch_att, [-1, 1, 1, ch])
    x = Multiply()([x, ch_att])

    avg = tf.reduce_mean(x, axis=-1, keepdims=True)
    mx = tf.reduce_max(x, axis=-1, keepdims=True)
    concat = Concatenate(axis=-1)([avg, mx])
    sp_att = Conv2D(1, (7,7), activation='sigmoid', padding='same', use_bias=False)(concat)
    x = Multiply()([x, sp_att])
    return x

# %% [markdown]
# EfficientNetV2S Model

# %% [markdown]
# (Stage 1 - Frozen)

# %%
base_model = EfficientNetV2S(weights='imagenet',
                             include_top=False,
                             input_shape=(224, 224, 3))

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
x = base_model.output
x = cbam_block(x)
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)        # was 128
x = BatchNormalization()(x)                 # helps regularize and stabilize training
x = Dropout(0.4)(x)                         # was 0.5
predictions = Dense(4, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)


# Compile the model
model.compile(
    optimizer=AdamW(learning_rate=5e-4, weight_decay=1e-4),  # AdamW instead of plain Adam
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# Model Training

# %%
epochs = 50
batch_size = 16

# %%
history = model.fit(
    datagen.flow(train_data, train_labels, batch_size=batch_size),
    validation_data=val_datagen.flow(val_data, val_labels, batch_size=batch_size, shuffle=False),
    epochs=epochs,
    callbacks=callback_list
)
# Out:
# Epoch 1/50
# 290/290 [==============================] - ETA: 0s - loss: 1.1405 - accuracy: 0.5073
# Epoch 1: val_accuracy improved from -inf to 0.52529, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# c:\Users\falco\Desktop\emp\.venv_gpu\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 290/290 [==============================] - 240s 783ms/step - loss: 1.1405 - accuracy: 0.5073 - val_loss: 1.1262 - val_accuracy: 0.5253 - lr: 5.0000e-04
# Epoch 2/50
# 290/290 [==============================] - ETA: 0s - loss: 1.0502 - accuracy: 0.5473
# Epoch 2: val_accuracy improved from 0.52529 to 0.53113, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# 290/290 [==============================] - 227s 782ms/step - loss: 1.0502 - accuracy: 0.5473 - val_loss: 1.2734 - val_accuracy: 0.5311 - lr: 5.0000e-04
# Epoch 3/50
# 290/290 [==============================] - ETA: 0s - loss: 1.0036 - accuracy: 0.5607
# Epoch 3: val_accuracy did not improve from 0.53113
# 290/290 [==============================] - 228s 785ms/step - loss: 1.0036 - accuracy: 0.5607 - val_loss: 1.3732 - val_accuracy: 0.4903 - lr: 5.0000e-04
# Epoch 4/50
# 290/290 [==============================] - ETA: 0s - loss: 0.9971 - accuracy: 0.5746
# Epoch 4: val_accuracy improved from 0.53113 to 0.55642, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# 290/290 [==============================] - 229s 788ms/step - loss: 0.9971 - accuracy: 0.5746 - val_loss: 1.0796 - val_accuracy: 0.5564 - lr: 5.0000e-04
# Epoch 5/50
# 290/290 [==============================] - ETA: 0s - loss: 0.9598 - accuracy: 0.5832
# Epoch 5: val_accuracy improved from 0.55642 to 0.57004, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# 290/290 [==============================] - 228s 785ms/step - loss: 0.9598 - accuracy: 0.5832 - val_loss: 0.9718 - val_accuracy: 0.5700 - lr: 5.0000e-04
# Epoch 6/50
# 290/290 [==============================] - ETA: 0s - loss: 0.9420 - accuracy: 0.5960
# Epoch 6: val_accuracy improved from 0.57004 to 0.57588, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# 290/290 [==============================] - 237s 816ms/step - loss: 0.9420 - accuracy: 0.5960 - val_loss: 0.9213 - val_accuracy: 0.5759 - lr: 5.0000e-04
# Epoch 7/50
# 290/290 [==============================] - ETA: 0s - loss: 0.9395 - accuracy: 0.6022
# Epoch 7: val_accuracy improved from 0.57588 to 0.67315, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# 290/290 [==============================] - 242s 833ms/step - loss: 0.9395 - accuracy: 0.6022 - val_loss: 0.8294 - val_accuracy: 0.6732 - lr: 5.0000e-04
# Epoch 8/50
# 290/290 [==============================] - ETA: 0s - loss: 0.9270 - accuracy: 0.6046
# Epoch 8: val_accuracy improved from 0.67315 to 0.71206, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# 290/290 [==============================] - 225s 776ms/step - loss: 0.9270 - accuracy: 0.6046 - val_loss: 0.7852 - val_accuracy: 0.7121 - lr: 5.0000e-04
# Epoch 9/50
# 290/290 [==============================] - ETA: 0s - loss: 0.9193 - accuracy: 0.6096
# Epoch 9: val_accuracy did not improve from 0.71206
# 290/290 [==============================] - 226s 780ms/step - loss: 0.9193 - accuracy: 0.6096 - val_loss: 1.0436 - val_accuracy: 0.5603 - lr: 5.0000e-04
# Epoch 10/50
# 290/290 [==============================] - ETA: 0s - loss: 0.9092 - accuracy: 0.6163
# Epoch 10: val_accuracy did not improve from 0.71206
# 290/290 [==============================] - 226s 780ms/step - loss: 0.9092 - accuracy: 0.6163 - val_loss: 0.9441 - val_accuracy: 0.5661 - lr: 5.0000e-04
# Epoch 11/50
# 290/290 [==============================] - ETA: 0s - loss: 0.9047 - accuracy: 0.6087
# Epoch 11: val_accuracy did not improve from 0.71206
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 290/290 [==============================] - 226s 779ms/step - loss: 0.9047 - accuracy: 0.6087 - val_loss: 1.4954 - val_accuracy: 0.5058 - lr: 5.0000e-04
# Epoch 12/50
# 290/290 [==============================] - ETA: 0s - loss: 0.8921 - accuracy: 0.6221
# Epoch 12: val_accuracy did not improve from 0.71206
# 290/290 [==============================] - 227s 784ms/step - loss: 0.8921 - accuracy: 0.6221 - val_loss: 0.7602 - val_accuracy: 0.7101 - lr: 2.5000e-04
# Epoch 13/50
# 290/290 [==============================] - ETA: 0s - loss: 0.8899 - accuracy: 0.6282
# Epoch 13: val_accuracy did not improve from 0.71206
# 290/290 [==============================] - 233s 802ms/step - loss: 0.8899 - accuracy: 0.6282 - val_loss: 0.7574 - val_accuracy: 0.7043 - lr: 2.5000e-04
# Epoch 14/50
# 290/290 [==============================] - ETA: 0s - loss: 0.8806 - accuracy: 0.6267
# Epoch 14: val_accuracy improved from 0.71206 to 0.72374, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# 290/290 [==============================] - 238s 821ms/step - loss: 0.8806 - accuracy: 0.6267 - val_loss: 0.7425 - val_accuracy: 0.7237 - lr: 2.5000e-04
# Epoch 15/50
# 290/290 [==============================] - ETA: 0s - loss: 0.8878 - accuracy: 0.6252
# Epoch 15: val_accuracy did not improve from 0.72374
# 290/290 [==============================] - 230s 792ms/step - loss: 0.8878 - accuracy: 0.6252 - val_loss: 0.7796 - val_accuracy: 0.6848 - lr: 2.5000e-04
# Epoch 16/50
# 290/290 [==============================] - ETA: 0s - loss: 0.8771 - accuracy: 0.6375
# Epoch 16: val_accuracy did not improve from 0.72374
# 290/290 [==============================] - 224s 773ms/step - loss: 0.8771 - accuracy: 0.6375 - val_loss: 0.7990 - val_accuracy: 0.6868 - lr: 2.5000e-04
# Epoch 17/50
# 290/290 [==============================] - ETA: 0s - loss: 0.8931 - accuracy: 0.6293
# Epoch 17: val_accuracy did not improve from 0.72374
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 290/290 [==============================] - 238s 821ms/step - loss: 0.8931 - accuracy: 0.6293 - val_loss: 0.8311 - val_accuracy: 0.6518 - lr: 2.5000e-04
# Epoch 18/50
# 290/290 [==============================] - ETA: 0s - loss: 0.8770 - accuracy: 0.6336
# Epoch 18: val_accuracy improved from 0.72374 to 0.73346, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# 290/290 [==============================] - 241s 829ms/step - loss: 0.8770 - accuracy: 0.6336 - val_loss: 0.7349 - val_accuracy: 0.7335 - lr: 1.2500e-04
# Epoch 19/50
# 290/290 [==============================] - ETA: 0s - loss: 0.8642 - accuracy: 0.6383
# Epoch 19: val_accuracy did not improve from 0.73346
# 290/290 [==============================] - 222s 764ms/step - loss: 0.8642 - accuracy: 0.6383 - val_loss: 0.7644 - val_accuracy: 0.6809 - lr: 1.2500e-04
# Epoch 20/50
# 290/290 [==============================] - ETA: 0s - loss: 0.8697 - accuracy: 0.6386
# Epoch 20: val_accuracy improved from 0.73346 to 0.73735, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# 290/290 [==============================] - 222s 767ms/step - loss: 0.8697 - accuracy: 0.6386 - val_loss: 0.7387 - val_accuracy: 0.7374 - lr: 1.2500e-04
# Epoch 21/50
# 290/290 [==============================] - ETA: 0s - loss: 0.8661 - accuracy: 0.6427
# Epoch 21: val_accuracy improved from 0.73735 to 0.74514, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# 290/290 [==============================] - 225s 775ms/step - loss: 0.8661 - accuracy: 0.6427 - val_loss: 0.6983 - val_accuracy: 0.7451 - lr: 1.2500e-04
# Epoch 22/50
# 290/290 [==============================] - ETA: 0s - loss: 0.8657 - accuracy: 0.6381
# Epoch 22: val_accuracy did not improve from 0.74514
# 290/290 [==============================] - 226s 780ms/step - loss: 0.8657 - accuracy: 0.6381 - val_loss: 0.7104 - val_accuracy: 0.7412 - lr: 1.2500e-04
# Epoch 23/50
# 290/290 [==============================] - ETA: 0s - loss: 0.8712 - accuracy: 0.6304
# Epoch 23: val_accuracy did not improve from 0.74514
# 290/290 [==============================] - 226s 780ms/step - loss: 0.8712 - accuracy: 0.6304 - val_loss: 0.7075 - val_accuracy: 0.7198 - lr: 1.2500e-04
# Epoch 24/50
# 290/290 [==============================] - ETA: 0s - loss: 0.8630 - accuracy: 0.6362
# Epoch 24: val_accuracy did not improve from 0.74514
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 290/290 [==============================] - 226s 780ms/step - loss: 0.8630 - accuracy: 0.6362 - val_loss: 0.7738 - val_accuracy: 0.6829 - lr: 1.2500e-04
# Epoch 25/50
# 290/290 [==============================] - ETA: 0s - loss: 0.8653 - accuracy: 0.6340
# Epoch 25: val_accuracy did not improve from 0.74514
# 290/290 [==============================] - 226s 779ms/step - loss: 0.8653 - accuracy: 0.6340 - val_loss: 0.6983 - val_accuracy: 0.7296 - lr: 6.2500e-05
# Epoch 26/50
# 290/290 [==============================] - ETA: 0s - loss: 0.8502 - accuracy: 0.6340
# Epoch 26: val_accuracy did not improve from 0.74514
# 290/290 [==============================] - 226s 778ms/step - loss: 0.8502 - accuracy: 0.6340 - val_loss: 0.6983 - val_accuracy: 0.7315 - lr: 6.2500e-05
# Epoch 27/50
# 290/290 [==============================] - ETA: 0s - loss: 0.8446 - accuracy: 0.6515
# Epoch 27: val_accuracy did not improve from 0.74514
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 290/290 [==============================] - 226s 778ms/step - loss: 0.8446 - accuracy: 0.6515 - val_loss: 0.7008 - val_accuracy: 0.7354 - lr: 6.2500e-05
# Epoch 28/50
# 290/290 [==============================] - ETA: 0s - loss: 0.8479 - accuracy: 0.6444
# Epoch 28: val_accuracy improved from 0.74514 to 0.75097, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# 290/290 [==============================] - 226s 780ms/step - loss: 0.8479 - accuracy: 0.6444 - val_loss: 0.6787 - val_accuracy: 0.7510 - lr: 3.1250e-05
# Epoch 29/50
# 290/290 [==============================] - ETA: 0s - loss: 0.8340 - accuracy: 0.6518
# Epoch 29: val_accuracy did not improve from 0.75097
# 290/290 [==============================] - 227s 782ms/step - loss: 0.8340 - accuracy: 0.6518 - val_loss: 0.7138 - val_accuracy: 0.7062 - lr: 3.1250e-05
# Epoch 30/50
# 290/290 [==============================] - ETA: 0s - loss: 0.8368 - accuracy: 0.6502
# Epoch 30: val_accuracy did not improve from 0.75097
# 290/290 [==============================] - 227s 781ms/step - loss: 0.8368 - accuracy: 0.6502 - val_loss: 0.7132 - val_accuracy: 0.7043 - lr: 3.1250e-05
# Epoch 31/50
# 290/290 [==============================] - ETA: 0s - loss: 0.8494 - accuracy: 0.6479
# Epoch 31: val_accuracy did not improve from 0.75097
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 290/290 [==============================] - 226s 779ms/step - loss: 0.8494 - accuracy: 0.6479 - val_loss: 0.6943 - val_accuracy: 0.7257 - lr: 3.1250e-05
# Epoch 32/50
# 290/290 [==============================] - ETA: 0s - loss: 0.8409 - accuracy: 0.6539
# Epoch 32: val_accuracy did not improve from 0.75097
# 290/290 [==============================] - 226s 780ms/step - loss: 0.8409 - accuracy: 0.6539 - val_loss: 0.7135 - val_accuracy: 0.7043 - lr: 1.5625e-05
# Epoch 33/50
# 290/290 [==============================] - ETA: 0s - loss: 0.8418 - accuracy: 0.6463
# Epoch 33: val_accuracy did not improve from 0.75097
# 290/290 [==============================] - 226s 779ms/step - loss: 0.8418 - accuracy: 0.6463 - val_loss: 0.7015 - val_accuracy: 0.7121 - lr: 1.5625e-05
# Epoch 34/50
# 290/290 [==============================] - ETA: 0s - loss: 0.8458 - accuracy: 0.6479
# Epoch 34: val_accuracy did not improve from 0.75097
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 290/290 [==============================] - 226s 780ms/step - loss: 0.8458 - accuracy: 0.6479 - val_loss: 0.6830 - val_accuracy: 0.7257 - lr: 1.5625e-05
# Epoch 35/50
# 290/290 [==============================] - ETA: 0s - loss: 0.8410 - accuracy: 0.6494
# Epoch 35: val_accuracy did not improve from 0.75097
# Restoring model weights from the end of the best epoch: 28.
# 290/290 [==============================] - 226s 780ms/step - loss: 0.8410 - accuracy: 0.6494 - val_loss: 0.6907 - val_accuracy: 0.7198 - lr: 7.8125e-06
# Epoch 35: early stopping

# %% [markdown]
# Stage 2 - Fine-Tuning

# %%
model.save(r"C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.keras")

# %%
model = load_model(r"C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.keras", compile=False)

unfrozen_count = 0
for layer in model.layers:
    if any(x in layer.name for x in ["block", "stem", "top_conv"]):
        layer.trainable = True
        unfrozen_count += 1

print(f"Unfrozen EfficientNet: {unfrozen_count}")

trainable_params = np.sum([np.prod(v.shape) for v in model.trainable_weights])
print(f"Trainable params before compile: {trainable_params:,}")


model.compile(
    optimizer=AdamW(learning_rate=1e-5, weight_decay=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# Unfrozen EfficientNet: 509
# Trainable params before compile: 20,914,102

# %%
model.summary(line_length=120, expand_nested=True)
# Out:
# Model: "model"
# ________________________________________________________________________________________________________________________
#  Layer (type)                       Output Shape                        Param #     Connected to
# ========================================================================================================================
#  input_1 (InputLayer)               [(None, 224, 224, 3)]               0           []
#
#  rescaling (Rescaling)              (None, 224, 224, 3)                 0           ['input_1[0][0]']
#
#  stem_conv (Conv2D)                 (None, 112, 112, 24)                648         ['rescaling[0][0]']
#
#  stem_bn (BatchNormalization)       (None, 112, 112, 24)                96          ['stem_conv[0][0]']
#
#  stem_activation (Activation)       (None, 112, 112, 24)                0           ['stem_bn[0][0]']
#
#  block1a_project_conv (Conv2D)      (None, 112, 112, 24)                5184        ['stem_activation[0][0]']
#
#  block1a_project_bn (BatchNormaliz  (None, 112, 112, 24)                96          ['block1a_project_conv[0][0]']
#  ation)
#
#  block1a_project_activation (Activ  (None, 112, 112, 24)                0           ['block1a_project_bn[0][0]']
#  ation)
#
#  block1a_add (Add)                  (None, 112, 112, 24)                0           ['block1a_project_activation[0][0]',
#                                                                                      'stem_activation[0][0]']
#
#  block1b_project_conv (Conv2D)      (None, 112, 112, 24)                5184        ['block1a_add[0][0]']
#
#  block1b_project_bn (BatchNormaliz  (None, 112, 112, 24)                96          ['block1b_project_conv[0][0]']
#  ation)
#
#  block1b_project_activation (Activ  (None, 112, 112, 24)                0           ['block1b_project_bn[0][0]']
#  ation)
#
#  block1b_drop (Dropout)             (None, 112, 112, 24)                0           ['block1b_project_activation[0][0]']
#
#  block1b_add (Add)                  (None, 112, 112, 24)                0           ['block1b_drop[0][0]',
#                                                                                      'block1a_add[0][0]']
#
#  block2a_expand_conv (Conv2D)       (None, 56, 56, 96)                  20736       ['block1b_add[0][0]']
#
#  block2a_expand_bn (BatchNormaliza  (None, 56, 56, 96)                  384         ['block2a_expand_conv[0][0]']
#  tion)
#
#  block2a_expand_activation (Activa  (None, 56, 56, 96)                  0           ['block2a_expand_bn[0][0]']
#  tion)
#
#  block2a_project_conv (Conv2D)      (None, 56, 56, 48)                  4608        ['block2a_expand_activation[0][0]']
#
#  block2a_project_bn (BatchNormaliz  (None, 56, 56, 48)                  192         ['block2a_project_conv[0][0]']
#  ation)
#
#  block2b_expand_conv (Conv2D)       (None, 56, 56, 192)                 82944       ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormaliza  (None, 56, 56, 192)                 768         ['block2b_expand_conv[0][0]']
#  tion)
#
#  block2b_expand_activation (Activa  (None, 56, 56, 192)                 0           ['block2b_expand_bn[0][0]']
#  tion)
#
#  block2b_project_conv (Conv2D)      (None, 56, 56, 48)                  9216        ['block2b_expand_activation[0][0]']
#
#  block2b_project_bn (BatchNormaliz  (None, 56, 56, 48)                  192         ['block2b_project_conv[0][0]']
#  ation)
#
#  block2b_drop (Dropout)             (None, 56, 56, 48)                  0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)                  (None, 56, 56, 48)                  0           ['block2b_drop[0][0]',
#                                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)       (None, 56, 56, 192)                 82944       ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormaliza  (None, 56, 56, 192)                 768         ['block2c_expand_conv[0][0]']
#  tion)
#
#  block2c_expand_activation (Activa  (None, 56, 56, 192)                 0           ['block2c_expand_bn[0][0]']
#  tion)
#
#  block2c_project_conv (Conv2D)      (None, 56, 56, 48)                  9216        ['block2c_expand_activation[0][0]']
#
#  block2c_project_bn (BatchNormaliz  (None, 56, 56, 48)                  192         ['block2c_project_conv[0][0]']
#  ation)
#
#  block2c_drop (Dropout)             (None, 56, 56, 48)                  0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)                  (None, 56, 56, 48)                  0           ['block2c_drop[0][0]',
#                                                                                      'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)       (None, 56, 56, 192)                 82944       ['block2c_add[0][0]']
#
#  block2d_expand_bn (BatchNormaliza  (None, 56, 56, 192)                 768         ['block2d_expand_conv[0][0]']
#  tion)
#
#  block2d_expand_activation (Activa  (None, 56, 56, 192)                 0           ['block2d_expand_bn[0][0]']
#  tion)
#
#  block2d_project_conv (Conv2D)      (None, 56, 56, 48)                  9216        ['block2d_expand_activation[0][0]']
#
#  block2d_project_bn (BatchNormaliz  (None, 56, 56, 48)                  192         ['block2d_project_conv[0][0]']
#  ation)
#
#  block2d_drop (Dropout)             (None, 56, 56, 48)                  0           ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)                  (None, 56, 56, 48)                  0           ['block2d_drop[0][0]',
#                                                                                      'block2c_add[0][0]']
#
#  block3a_expand_conv (Conv2D)       (None, 28, 28, 192)                 82944       ['block2d_add[0][0]']
#
#  block3a_expand_bn (BatchNormaliza  (None, 28, 28, 192)                 768         ['block3a_expand_conv[0][0]']
#  tion)
#
#  block3a_expand_activation (Activa  (None, 28, 28, 192)                 0           ['block3a_expand_bn[0][0]']
#  tion)
#
#  block3a_project_conv (Conv2D)      (None, 28, 28, 64)                  12288       ['block3a_expand_activation[0][0]']
#
#  block3a_project_bn (BatchNormaliz  (None, 28, 28, 64)                  256         ['block3a_project_conv[0][0]']
#  ation)
#
#  block3b_expand_conv (Conv2D)       (None, 28, 28, 256)                 147456      ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormaliza  (None, 28, 28, 256)                 1024        ['block3b_expand_conv[0][0]']
#  tion)
#
#  block3b_expand_activation (Activa  (None, 28, 28, 256)                 0           ['block3b_expand_bn[0][0]']
#  tion)
#
#  block3b_project_conv (Conv2D)      (None, 28, 28, 64)                  16384       ['block3b_expand_activation[0][0]']
#
#  block3b_project_bn (BatchNormaliz  (None, 28, 28, 64)                  256         ['block3b_project_conv[0][0]']
#  ation)
#
#  block3b_drop (Dropout)             (None, 28, 28, 64)                  0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)                  (None, 28, 28, 64)                  0           ['block3b_drop[0][0]',
#                                                                                      'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)       (None, 28, 28, 256)                 147456      ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormaliza  (None, 28, 28, 256)                 1024        ['block3c_expand_conv[0][0]']
#  tion)
#
#  block3c_expand_activation (Activa  (None, 28, 28, 256)                 0           ['block3c_expand_bn[0][0]']
#  tion)
#
#  block3c_project_conv (Conv2D)      (None, 28, 28, 64)                  16384       ['block3c_expand_activation[0][0]']
#
#  block3c_project_bn (BatchNormaliz  (None, 28, 28, 64)                  256         ['block3c_project_conv[0][0]']
#  ation)
#
#  block3c_drop (Dropout)             (None, 28, 28, 64)                  0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)                  (None, 28, 28, 64)                  0           ['block3c_drop[0][0]',
#                                                                                      'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)       (None, 28, 28, 256)                 147456      ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormaliza  (None, 28, 28, 256)                 1024        ['block3d_expand_conv[0][0]']
#  tion)
#
#  block3d_expand_activation (Activa  (None, 28, 28, 256)                 0           ['block3d_expand_bn[0][0]']
#  tion)
#
#  block3d_project_conv (Conv2D)      (None, 28, 28, 64)                  16384       ['block3d_expand_activation[0][0]']
#
#  block3d_project_bn (BatchNormaliz  (None, 28, 28, 64)                  256         ['block3d_project_conv[0][0]']
#  ation)
#
#  block3d_drop (Dropout)             (None, 28, 28, 64)                  0           ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)                  (None, 28, 28, 64)                  0           ['block3d_drop[0][0]',
#                                                                                      'block3c_add[0][0]']
#
#  block4a_expand_conv (Conv2D)       (None, 28, 28, 256)                 16384       ['block3d_add[0][0]']
#
#  block4a_expand_bn (BatchNormaliza  (None, 28, 28, 256)                 1024        ['block4a_expand_conv[0][0]']
#  tion)
#
#  block4a_expand_activation (Activa  (None, 28, 28, 256)                 0           ['block4a_expand_bn[0][0]']
#  tion)
#
#  block4a_dwconv2 (DepthwiseConv2D)  (None, 14, 14, 256)                 2304        ['block4a_expand_activation[0][0]']
#
#  block4a_bn (BatchNormalization)    (None, 14, 14, 256)                 1024        ['block4a_dwconv2[0][0]']
#
#  block4a_activation (Activation)    (None, 14, 14, 256)                 0           ['block4a_bn[0][0]']
#
#  block4a_se_squeeze (GlobalAverage  (None, 256)                         0           ['block4a_activation[0][0]']
#  Pooling2D)
#
#  block4a_se_reshape (Reshape)       (None, 1, 1, 256)                   0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)         (None, 1, 1, 16)                    4112        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)         (None, 1, 1, 256)                   4352        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)       (None, 14, 14, 256)                 0           ['block4a_activation[0][0]',
#                                                                                      'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)      (None, 14, 14, 128)                 32768       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNormaliz  (None, 14, 14, 128)                 512         ['block4a_project_conv[0][0]']
#  ation)
#
#  block4b_expand_conv (Conv2D)       (None, 14, 14, 512)                 65536       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormaliza  (None, 14, 14, 512)                 2048        ['block4b_expand_conv[0][0]']
#  tion)
#
#  block4b_expand_activation (Activa  (None, 14, 14, 512)                 0           ['block4b_expand_bn[0][0]']
#  tion)
#
#  block4b_dwconv2 (DepthwiseConv2D)  (None, 14, 14, 512)                 4608        ['block4b_expand_activation[0][0]']
#
#  block4b_bn (BatchNormalization)    (None, 14, 14, 512)                 2048        ['block4b_dwconv2[0][0]']
#
#  block4b_activation (Activation)    (None, 14, 14, 512)                 0           ['block4b_bn[0][0]']
#
#  block4b_se_squeeze (GlobalAverage  (None, 512)                         0           ['block4b_activation[0][0]']
#  Pooling2D)
#
#  block4b_se_reshape (Reshape)       (None, 1, 1, 512)                   0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)         (None, 1, 1, 32)                    16416       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)         (None, 1, 1, 512)                   16896       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)       (None, 14, 14, 512)                 0           ['block4b_activation[0][0]',
#                                                                                      'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)      (None, 14, 14, 128)                 65536       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNormaliz  (None, 14, 14, 128)                 512         ['block4b_project_conv[0][0]']
#  ation)
#
#  block4b_drop (Dropout)             (None, 14, 14, 128)                 0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)                  (None, 14, 14, 128)                 0           ['block4b_drop[0][0]',
#                                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)       (None, 14, 14, 512)                 65536       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormaliza  (None, 14, 14, 512)                 2048        ['block4c_expand_conv[0][0]']
#  tion)
#
#  block4c_expand_activation (Activa  (None, 14, 14, 512)                 0           ['block4c_expand_bn[0][0]']
#  tion)
#
#  block4c_dwconv2 (DepthwiseConv2D)  (None, 14, 14, 512)                 4608        ['block4c_expand_activation[0][0]']
#
#  block4c_bn (BatchNormalization)    (None, 14, 14, 512)                 2048        ['block4c_dwconv2[0][0]']
#
#  block4c_activation (Activation)    (None, 14, 14, 512)                 0           ['block4c_bn[0][0]']
#
#  block4c_se_squeeze (GlobalAverage  (None, 512)                         0           ['block4c_activation[0][0]']
#  Pooling2D)
#
#  block4c_se_reshape (Reshape)       (None, 1, 1, 512)                   0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)         (None, 1, 1, 32)                    16416       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)         (None, 1, 1, 512)                   16896       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)       (None, 14, 14, 512)                 0           ['block4c_activation[0][0]',
#                                                                                      'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)      (None, 14, 14, 128)                 65536       ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNormaliz  (None, 14, 14, 128)                 512         ['block4c_project_conv[0][0]']
#  ation)
#
#  block4c_drop (Dropout)             (None, 14, 14, 128)                 0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)                  (None, 14, 14, 128)                 0           ['block4c_drop[0][0]',
#                                                                                      'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)       (None, 14, 14, 512)                 65536       ['block4c_add[0][0]']
#
#  block4d_expand_bn (BatchNormaliza  (None, 14, 14, 512)                 2048        ['block4d_expand_conv[0][0]']
#  tion)
#
#  block4d_expand_activation (Activa  (None, 14, 14, 512)                 0           ['block4d_expand_bn[0][0]']
#  tion)
#
#  block4d_dwconv2 (DepthwiseConv2D)  (None, 14, 14, 512)                 4608        ['block4d_expand_activation[0][0]']
#
#  block4d_bn (BatchNormalization)    (None, 14, 14, 512)                 2048        ['block4d_dwconv2[0][0]']
#
#  block4d_activation (Activation)    (None, 14, 14, 512)                 0           ['block4d_bn[0][0]']
#
#  block4d_se_squeeze (GlobalAverage  (None, 512)                         0           ['block4d_activation[0][0]']
#  Pooling2D)
#
#  block4d_se_reshape (Reshape)       (None, 1, 1, 512)                   0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)         (None, 1, 1, 32)                    16416       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)         (None, 1, 1, 512)                   16896       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)       (None, 14, 14, 512)                 0           ['block4d_activation[0][0]',
#                                                                                      'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)      (None, 14, 14, 128)                 65536       ['block4d_se_excite[0][0]']
#
#  block4d_project_bn (BatchNormaliz  (None, 14, 14, 128)                 512         ['block4d_project_conv[0][0]']
#  ation)
#
#  block4d_drop (Dropout)             (None, 14, 14, 128)                 0           ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)                  (None, 14, 14, 128)                 0           ['block4d_drop[0][0]',
#                                                                                      'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2D)       (None, 14, 14, 512)                 65536       ['block4d_add[0][0]']
#
#  block4e_expand_bn (BatchNormaliza  (None, 14, 14, 512)                 2048        ['block4e_expand_conv[0][0]']
#  tion)
#
#  block4e_expand_activation (Activa  (None, 14, 14, 512)                 0           ['block4e_expand_bn[0][0]']
#  tion)
#
#  block4e_dwconv2 (DepthwiseConv2D)  (None, 14, 14, 512)                 4608        ['block4e_expand_activation[0][0]']
#
#  block4e_bn (BatchNormalization)    (None, 14, 14, 512)                 2048        ['block4e_dwconv2[0][0]']
#
#  block4e_activation (Activation)    (None, 14, 14, 512)                 0           ['block4e_bn[0][0]']
#
#  block4e_se_squeeze (GlobalAverage  (None, 512)                         0           ['block4e_activation[0][0]']
#  Pooling2D)
#
#  block4e_se_reshape (Reshape)       (None, 1, 1, 512)                   0           ['block4e_se_squeeze[0][0]']
#
#  block4e_se_reduce (Conv2D)         (None, 1, 1, 32)                    16416       ['block4e_se_reshape[0][0]']
#
#  block4e_se_expand (Conv2D)         (None, 1, 1, 512)                   16896       ['block4e_se_reduce[0][0]']
#
#  block4e_se_excite (Multiply)       (None, 14, 14, 512)                 0           ['block4e_activation[0][0]',
#                                                                                      'block4e_se_expand[0][0]']
#
#  block4e_project_conv (Conv2D)      (None, 14, 14, 128)                 65536       ['block4e_se_excite[0][0]']
#
#  block4e_project_bn (BatchNormaliz  (None, 14, 14, 128)                 512         ['block4e_project_conv[0][0]']
#  ation)
#
#  block4e_drop (Dropout)             (None, 14, 14, 128)                 0           ['block4e_project_bn[0][0]']
#
#  block4e_add (Add)                  (None, 14, 14, 128)                 0           ['block4e_drop[0][0]',
#                                                                                      'block4d_add[0][0]']
#
#  block4f_expand_conv (Conv2D)       (None, 14, 14, 512)                 65536       ['block4e_add[0][0]']
#
#  block4f_expand_bn (BatchNormaliza  (None, 14, 14, 512)                 2048        ['block4f_expand_conv[0][0]']
#  tion)
#
#  block4f_expand_activation (Activa  (None, 14, 14, 512)                 0           ['block4f_expand_bn[0][0]']
#  tion)
#
#  block4f_dwconv2 (DepthwiseConv2D)  (None, 14, 14, 512)                 4608        ['block4f_expand_activation[0][0]']
#
#  block4f_bn (BatchNormalization)    (None, 14, 14, 512)                 2048        ['block4f_dwconv2[0][0]']
#
#  block4f_activation (Activation)    (None, 14, 14, 512)                 0           ['block4f_bn[0][0]']
#
#  block4f_se_squeeze (GlobalAverage  (None, 512)                         0           ['block4f_activation[0][0]']
#  Pooling2D)
#
#  block4f_se_reshape (Reshape)       (None, 1, 1, 512)                   0           ['block4f_se_squeeze[0][0]']
#
#  block4f_se_reduce (Conv2D)         (None, 1, 1, 32)                    16416       ['block4f_se_reshape[0][0]']
#
#  block4f_se_expand (Conv2D)         (None, 1, 1, 512)                   16896       ['block4f_se_reduce[0][0]']
#
#  block4f_se_excite (Multiply)       (None, 14, 14, 512)                 0           ['block4f_activation[0][0]',
#                                                                                      'block4f_se_expand[0][0]']
#
#  block4f_project_conv (Conv2D)      (None, 14, 14, 128)                 65536       ['block4f_se_excite[0][0]']
#
#  block4f_project_bn (BatchNormaliz  (None, 14, 14, 128)                 512         ['block4f_project_conv[0][0]']
#  ation)
#
#  block4f_drop (Dropout)             (None, 14, 14, 128)                 0           ['block4f_project_bn[0][0]']
#
#  block4f_add (Add)                  (None, 14, 14, 128)                 0           ['block4f_drop[0][0]',
#                                                                                      'block4e_add[0][0]']
#
#  block5a_expand_conv (Conv2D)       (None, 14, 14, 768)                 98304       ['block4f_add[0][0]']
#
#  block5a_expand_bn (BatchNormaliza  (None, 14, 14, 768)                 3072        ['block5a_expand_conv[0][0]']
#  tion)
#
#  block5a_expand_activation (Activa  (None, 14, 14, 768)                 0           ['block5a_expand_bn[0][0]']
#  tion)
#
#  block5a_dwconv2 (DepthwiseConv2D)  (None, 14, 14, 768)                 6912        ['block5a_expand_activation[0][0]']
#
#  block5a_bn (BatchNormalization)    (None, 14, 14, 768)                 3072        ['block5a_dwconv2[0][0]']
#
#  block5a_activation (Activation)    (None, 14, 14, 768)                 0           ['block5a_bn[0][0]']
#
# ...
#  ation)
#
#  block6m_drop (Dropout)             (None, 7, 7, 256)                   0           ['block6m_project_bn[0][0]']
#
#  block6m_add (Add)                  (None, 7, 7, 256)                   0           ['block6m_drop[0][0]',
#                                                                                      'block6l_add[0][0]']
#
#  block6n_expand_conv (Conv2D)       (None, 7, 7, 1536)                  393216      ['block6m_add[0][0]']
#
#  block6n_expand_bn (BatchNormaliza  (None, 7, 7, 1536)                  6144        ['block6n_expand_conv[0][0]']
#  tion)
#
#  block6n_expand_activation (Activa  (None, 7, 7, 1536)                  0           ['block6n_expand_bn[0][0]']
#  tion)
#
#  block6n_dwconv2 (DepthwiseConv2D)  (None, 7, 7, 1536)                  13824       ['block6n_expand_activation[0][0]']
#
#  block6n_bn (BatchNormalization)    (None, 7, 7, 1536)                  6144        ['block6n_dwconv2[0][0]']
#
#  block6n_activation (Activation)    (None, 7, 7, 1536)                  0           ['block6n_bn[0][0]']
#
#  block6n_se_squeeze (GlobalAverage  (None, 1536)                        0           ['block6n_activation[0][0]']
#  Pooling2D)
#
#  block6n_se_reshape (Reshape)       (None, 1, 1, 1536)                  0           ['block6n_se_squeeze[0][0]']
#
#  block6n_se_reduce (Conv2D)         (None, 1, 1, 64)                    98368       ['block6n_se_reshape[0][0]']
#
#  block6n_se_expand (Conv2D)         (None, 1, 1, 1536)                  99840       ['block6n_se_reduce[0][0]']
#
#  block6n_se_excite (Multiply)       (None, 7, 7, 1536)                  0           ['block6n_activation[0][0]',
#                                                                                      'block6n_se_expand[0][0]']
#
#  block6n_project_conv (Conv2D)      (None, 7, 7, 256)                   393216      ['block6n_se_excite[0][0]']
#
#  block6n_project_bn (BatchNormaliz  (None, 7, 7, 256)                   1024        ['block6n_project_conv[0][0]']
#  ation)
#
#  block6n_drop (Dropout)             (None, 7, 7, 256)                   0           ['block6n_project_bn[0][0]']
#
#  block6n_add (Add)                  (None, 7, 7, 256)                   0           ['block6n_drop[0][0]',
#                                                                                      'block6m_add[0][0]']
#
#  block6o_expand_conv (Conv2D)       (None, 7, 7, 1536)                  393216      ['block6n_add[0][0]']
#
#  block6o_expand_bn (BatchNormaliza  (None, 7, 7, 1536)                  6144        ['block6o_expand_conv[0][0]']
#  tion)
#
#  block6o_expand_activation (Activa  (None, 7, 7, 1536)                  0           ['block6o_expand_bn[0][0]']
#  tion)
#
#  block6o_dwconv2 (DepthwiseConv2D)  (None, 7, 7, 1536)                  13824       ['block6o_expand_activation[0][0]']
#
#  block6o_bn (BatchNormalization)    (None, 7, 7, 1536)                  6144        ['block6o_dwconv2[0][0]']
#
#  block6o_activation (Activation)    (None, 7, 7, 1536)                  0           ['block6o_bn[0][0]']
#
#  block6o_se_squeeze (GlobalAverage  (None, 1536)                        0           ['block6o_activation[0][0]']
#  Pooling2D)
#
#  block6o_se_reshape (Reshape)       (None, 1, 1, 1536)                  0           ['block6o_se_squeeze[0][0]']
#
#  block6o_se_reduce (Conv2D)         (None, 1, 1, 64)                    98368       ['block6o_se_reshape[0][0]']
#
#  block6o_se_expand (Conv2D)         (None, 1, 1, 1536)                  99840       ['block6o_se_reduce[0][0]']
#
#  block6o_se_excite (Multiply)       (None, 7, 7, 1536)                  0           ['block6o_activation[0][0]',
#                                                                                      'block6o_se_expand[0][0]']
#
#  block6o_project_conv (Conv2D)      (None, 7, 7, 256)                   393216      ['block6o_se_excite[0][0]']
#
#  block6o_project_bn (BatchNormaliz  (None, 7, 7, 256)                   1024        ['block6o_project_conv[0][0]']
#  ation)
#
#  block6o_drop (Dropout)             (None, 7, 7, 256)                   0           ['block6o_project_bn[0][0]']
#
#  block6o_add (Add)                  (None, 7, 7, 256)                   0           ['block6o_drop[0][0]',
#                                                                                      'block6n_add[0][0]']
#
#  top_conv (Conv2D)                  (None, 7, 7, 1280)                  327680      ['block6o_add[0][0]']
#
#  top_bn (BatchNormalization)        (None, 7, 7, 1280)                  5120        ['top_conv[0][0]']
#
#  top_activation (Activation)        (None, 7, 7, 1280)                  0           ['top_bn[0][0]']
#
#  global_average_pooling2d (GlobalA  (None, 1280)                        0           ['top_activation[0][0]']
#  veragePooling2D)
#
#  global_max_pooling2d (GlobalMaxPo  (None, 1280)                        0           ['top_activation[0][0]']
#  oling2D)
#
#  dense (Dense)                      (None, 160)                         204800      ['global_average_pooling2d[0][0]',
#                                                                                      'global_max_pooling2d[0][0]']
#
#  dense_1 (Dense)                    (None, 1280)                        204800      ['dense[0][0]',
#                                                                                      'dense[1][0]']
#
#  add (Add)                          (None, 1280)                        0           ['dense_1[0][0]',
#                                                                                      'dense_1[1][0]']
#
#  tf.reshape (TFOpLambda)            (None, 1, 1, 1280)                  0           ['add[0][0]']
#
#  multiply (Multiply)                (None, 7, 7, 1280)                  0           ['top_activation[0][0]',
#                                                                                      'tf.reshape[0][0]']
#
#  tf.math.reduce_mean (TFOpLambda)   (None, 7, 7, 1)                     0           ['multiply[0][0]']
#
#  tf.math.reduce_max (TFOpLambda)    (None, 7, 7, 1)                     0           ['multiply[0][0]']
#
#  concatenate (Concatenate)          (None, 7, 7, 2)                     0           ['tf.math.reduce_mean[0][0]',
#                                                                                      'tf.math.reduce_max[0][0]']
#
#  conv2d (Conv2D)                    (None, 7, 7, 1)                     98          ['concatenate[0][0]']
#
#  multiply_1 (Multiply)              (None, 7, 7, 1280)                  0           ['multiply[0][0]',
#                                                                                      'conv2d[0][0]']
#
#  global_average_pooling2d_1 (Globa  (None, 1280)                        0           ['multiply_1[0][0]']
#  lAveragePooling2D)
#
#  dense_2 (Dense)                    (None, 256)                         327936      ['global_average_pooling2d_1[0][0]']
#
#  batch_normalization (BatchNormali  (None, 256)                         1024        ['dense_2[0][0]']
#  zation)
#
#  dropout (Dropout)                  (None, 256)                         0           ['batch_normalization[0][0]']
#
#  dense_3 (Dense)                    (None, 4)                           1028        ['dropout[0][0]']
#
# ========================================================================================================================
# Total params: 21071046 (80.38 MB)
# Trainable params: 20914102 (79.78 MB)
# Non-trainable params: 156944 (613.06 KB)
# ________________________________________________________________________________________________________________________

# %%
history_ft = model.fit(
    datagen.flow(train_data, train_labels, batch_size=batch_size),
    validation_data=val_datagen.flow(val_data, val_labels, batch_size=batch_size, shuffle=False),
    epochs=15,
    callbacks=callback_list
)
# Out:
# Epoch 1/15
# 290/290 [==============================] - ETA: 0s - loss: 0.9740 - accuracy: 0.5958
# Epoch 1: val_accuracy improved from 0.75097 to 0.80350, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# 290/290 [==============================] - 1027s 3s/step - loss: 0.9740 - accuracy: 0.5958 - val_loss: 0.5285 - val_accuracy: 0.8035 - lr: 1.0000e-05
# Epoch 2/15
# 290/290 [==============================] - ETA: 0s - loss: 0.6543 - accuracy: 0.7534
# Epoch 2: val_accuracy improved from 0.80350 to 0.82685, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# 290/290 [==============================] - 975s 3s/step - loss: 0.6543 - accuracy: 0.7534 - val_loss: 0.4650 - val_accuracy: 0.8268 - lr: 1.0000e-05
# Epoch 3/15
# 290/290 [==============================] - ETA: 0s - loss: 0.5511 - accuracy: 0.8011
# Epoch 3: val_accuracy improved from 0.82685 to 0.85992, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# 290/290 [==============================] - 980s 3s/step - loss: 0.5511 - accuracy: 0.8011 - val_loss: 0.4109 - val_accuracy: 0.8599 - lr: 1.0000e-05
# Epoch 4/15
# 290/290 [==============================] - ETA: 0s - loss: 0.4863 - accuracy: 0.8387
# Epoch 4: val_accuracy improved from 0.85992 to 0.88327, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# 290/290 [==============================] - 1024s 4s/step - loss: 0.4863 - accuracy: 0.8387 - val_loss: 0.3592 - val_accuracy: 0.8833 - lr: 1.0000e-05
# Epoch 5/15
# 290/290 [==============================] - ETA: 0s - loss: 0.4135 - accuracy: 0.8565
# Epoch 5: val_accuracy improved from 0.88327 to 0.88911, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# 290/290 [==============================] - 1038s 4s/step - loss: 0.4135 - accuracy: 0.8565 - val_loss: 0.3072 - val_accuracy: 0.8891 - lr: 1.0000e-05
# Epoch 6/15
# 290/290 [==============================] - ETA: 0s - loss: 0.3706 - accuracy: 0.8712
# Epoch 6: val_accuracy improved from 0.88911 to 0.90078, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# 290/290 [==============================] - 986s 3s/step - loss: 0.3706 - accuracy: 0.8712 - val_loss: 0.2899 - val_accuracy: 0.9008 - lr: 1.0000e-05
# Epoch 7/15
# 290/290 [==============================] - ETA: 0s - loss: 0.3440 - accuracy: 0.8783
# Epoch 7: val_accuracy improved from 0.90078 to 0.90661, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# 290/290 [==============================] - 1018s 4s/step - loss: 0.3440 - accuracy: 0.8783 - val_loss: 0.2554 - val_accuracy: 0.9066 - lr: 1.0000e-05
# Epoch 8/15
# 290/290 [==============================] - ETA: 0s - loss: 0.2866 - accuracy: 0.8978
# Epoch 8: val_accuracy improved from 0.90661 to 0.93191, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# 290/290 [==============================] - 1030s 4s/step - loss: 0.2866 - accuracy: 0.8978 - val_loss: 0.1972 - val_accuracy: 0.9319 - lr: 1.0000e-05
# Epoch 9/15
# 290/290 [==============================] - ETA: 0s - loss: 0.2701 - accuracy: 0.9008
# Epoch 9: val_accuracy improved from 0.93191 to 0.93580, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# 290/290 [==============================] - 989s 3s/step - loss: 0.2701 - accuracy: 0.9008 - val_loss: 0.1959 - val_accuracy: 0.9358 - lr: 1.0000e-05
# Epoch 10/15
# 290/290 [==============================] - ETA: 0s - loss: 0.2430 - accuracy: 0.9179
# Epoch 10: val_accuracy improved from 0.93580 to 0.94747, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# 290/290 [==============================] - 988s 3s/step - loss: 0.2430 - accuracy: 0.9179 - val_loss: 0.1753 - val_accuracy: 0.9475 - lr: 1.0000e-05
# Epoch 11/15
# 290/290 [==============================] - ETA: 0s - loss: 0.2255 - accuracy: 0.9192
# Epoch 11: val_accuracy did not improve from 0.94747
# 290/290 [==============================] - 986s 3s/step - loss: 0.2255 - accuracy: 0.9192 - val_loss: 0.1940 - val_accuracy: 0.9377 - lr: 1.0000e-05
# Epoch 12/15
# 290/290 [==============================] - ETA: 0s - loss: 0.2098 - accuracy: 0.9274
# Epoch 12: val_accuracy did not improve from 0.94747
# 290/290 [==============================] - 985s 3s/step - loss: 0.2098 - accuracy: 0.9274 - val_loss: 0.1773 - val_accuracy: 0.9455 - lr: 1.0000e-05
# Epoch 13/15
# 290/290 [==============================] - ETA: 0s - loss: 0.1914 - accuracy: 0.9336
# Epoch 13: val_accuracy did not improve from 0.94747
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 290/290 [==============================] - 986s 3s/step - loss: 0.1914 - accuracy: 0.9336 - val_loss: 0.1473 - val_accuracy: 0.9436 - lr: 1.0000e-05
# Epoch 14/15
# 290/290 [==============================] - ETA: 0s - loss: 0.1885 - accuracy: 0.9375
# Epoch 14: val_accuracy improved from 0.94747 to 0.95331, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# 290/290 [==============================] - 987s 3s/step - loss: 0.1885 - accuracy: 0.9375 - val_loss: 0.1352 - val_accuracy: 0.9533 - lr: 5.0000e-06
# Epoch 15/15
# 290/290 [==============================] - ETA: 0s - loss: 0.1798 - accuracy: 0.9377
# Epoch 15: val_accuracy improved from 0.95331 to 0.95914, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# 290/290 [==============================] - 992s 3s/step - loss: 0.1798 - accuracy: 0.9377 - val_loss: 0.1206 - val_accuracy: 0.9591 - lr: 5.0000e-06

# %%
model = load_model(r"C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5")

# %%
history_ft = model.fit(
    datagen.flow(train_data, train_labels, batch_size=batch_size),
    validation_data=val_datagen.flow(val_data, val_labels, batch_size=batch_size, shuffle=False),
    epochs=35,
    callbacks=callback_list
)
# Out:
# Epoch 1/35
# 290/290 [==============================] - ETA: 0s - loss: 0.1752 - accuracy: 0.9429
# Epoch 1: val_accuracy improved from -inf to 0.95331, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# c:\Users\falco\Desktop\emp\.venv_gpu\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 290/290 [==============================] - 1033s 3s/step - loss: 0.1752 - accuracy: 0.9429 - val_loss: 0.1278 - val_accuracy: 0.9533 - lr: 5.0000e-06
# Epoch 2/35
# 290/290 [==============================] - ETA: 0s - loss: 0.1587 - accuracy: 0.9457
# Epoch 2: val_accuracy improved from 0.95331 to 0.96498, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# 290/290 [==============================] - 1098s 4s/step - loss: 0.1587 - accuracy: 0.9457 - val_loss: 0.1106 - val_accuracy: 0.9650 - lr: 5.0000e-06
# Epoch 3/35
# 290/290 [==============================] - ETA: 0s - loss: 0.1676 - accuracy: 0.9412
# Epoch 3: val_accuracy did not improve from 0.96498
# 290/290 [==============================] - 983s 3s/step - loss: 0.1676 - accuracy: 0.9412 - val_loss: 0.1142 - val_accuracy: 0.9611 - lr: 5.0000e-06
# Epoch 4/35
# 290/290 [==============================] - ETA: 0s - loss: 0.1522 - accuracy: 0.9473
# Epoch 4: val_accuracy did not improve from 0.96498
# 290/290 [==============================] - 1014s 3s/step - loss: 0.1522 - accuracy: 0.9473 - val_loss: 0.0982 - val_accuracy: 0.9650 - lr: 5.0000e-06
# Epoch 5/35
# 290/290 [==============================] - ETA: 0s - loss: 0.1551 - accuracy: 0.9470
# Epoch 5: val_accuracy improved from 0.96498 to 0.96693, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# 290/290 [==============================] - 1043s 4s/step - loss: 0.1551 - accuracy: 0.9470 - val_loss: 0.1108 - val_accuracy: 0.9669 - lr: 5.0000e-06
# Epoch 6/35
# 290/290 [==============================] - ETA: 0s - loss: 0.1455 - accuracy: 0.9470
# Epoch 6: val_accuracy did not improve from 0.96693
# 290/290 [==============================] - 978s 3s/step - loss: 0.1455 - accuracy: 0.9470 - val_loss: 0.1214 - val_accuracy: 0.9591 - lr: 5.0000e-06
# Epoch 7/35
# 290/290 [==============================] - ETA: 0s - loss: 0.1279 - accuracy: 0.9559
# Epoch 7: val_accuracy did not improve from 0.96693
# 290/290 [==============================] - 977s 3s/step - loss: 0.1279 - accuracy: 0.9559 - val_loss: 0.1161 - val_accuracy: 0.9611 - lr: 5.0000e-06
# Epoch 8/35
# 290/290 [==============================] - ETA: 0s - loss: 0.1355 - accuracy: 0.9542
# Epoch 8: val_accuracy did not improve from 0.96693
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 290/290 [==============================] - 966s 3s/step - loss: 0.1355 - accuracy: 0.9542 - val_loss: 0.1133 - val_accuracy: 0.9553 - lr: 5.0000e-06
# Epoch 9/35
# 290/290 [==============================] - ETA: 0s - loss: 0.1323 - accuracy: 0.9540
# Epoch 9: val_accuracy improved from 0.96693 to 0.97082, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# 290/290 [==============================] - 1016s 4s/step - loss: 0.1323 - accuracy: 0.9540 - val_loss: 0.0969 - val_accuracy: 0.9708 - lr: 2.5000e-06
# Epoch 10/35
# 290/290 [==============================] - ETA: 0s - loss: 0.1360 - accuracy: 0.9537
# Epoch 10: val_accuracy did not improve from 0.97082
# 290/290 [==============================] - 999s 3s/step - loss: 0.1360 - accuracy: 0.9537 - val_loss: 0.1074 - val_accuracy: 0.9611 - lr: 2.5000e-06
# Epoch 11/35
# 290/290 [==============================] - ETA: 0s - loss: 0.1202 - accuracy: 0.9604
# Epoch 11: val_accuracy did not improve from 0.97082
# 290/290 [==============================] - 983s 3s/step - loss: 0.1202 - accuracy: 0.9604 - val_loss: 0.1086 - val_accuracy: 0.9591 - lr: 2.5000e-06
# Epoch 12/35
# 290/290 [==============================] - ETA: 0s - loss: 0.1233 - accuracy: 0.9633
# Epoch 12: val_accuracy did not improve from 0.97082
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 290/290 [==============================] - 1001s 3s/step - loss: 0.1233 - accuracy: 0.9633 - val_loss: 0.1086 - val_accuracy: 0.9630 - lr: 2.5000e-06
# Epoch 13/35
# 290/290 [==============================] - ETA: 0s - loss: 0.1247 - accuracy: 0.9591
# Epoch 13: val_accuracy did not improve from 0.97082
# 290/290 [==============================] - 994s 3s/step - loss: 0.1247 - accuracy: 0.9591 - val_loss: 0.0919 - val_accuracy: 0.9669 - lr: 1.2500e-06
# Epoch 14/35
# 290/290 [==============================] - ETA: 0s - loss: 0.1043 - accuracy: 0.9656
# Epoch 14: val_accuracy improved from 0.97082 to 0.97276, saving model to C:\Users\falco\Desktop\emp\SavedModels\EfficientNetV2S_CBAM.h5
# 290/290 [==============================] - 1029s 4s/step - loss: 0.1043 - accuracy: 0.9656 - val_loss: 0.0876 - val_accuracy: 0.9728 - lr: 1.2500e-06
# Epoch 15/35
# 290/290 [==============================] - ETA: 0s - loss: 0.1173 - accuracy: 0.9585
# Epoch 15: val_accuracy did not improve from 0.97276
# 290/290 [==============================] - 1024s 4s/step - loss: 0.1173 - accuracy: 0.9585 - val_loss: 0.0870 - val_accuracy: 0.9708 - lr: 1.2500e-06
# Epoch 16/35
# 290/290 [==============================] - ETA: 0s - loss: 0.1128 - accuracy: 0.9633
# Epoch 16: val_accuracy did not improve from 0.97276
# 290/290 [==============================] - 1005s 3s/step - loss: 0.1128 - accuracy: 0.9633 - val_loss: 0.0889 - val_accuracy: 0.9728 - lr: 1.2500e-06
# Epoch 17/35
# 290/290 [==============================] - ETA: 0s - loss: 0.1171 - accuracy: 0.9591
# Epoch 17: val_accuracy did not improve from 0.97276
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1e-06.
# 290/290 [==============================] - 991s 3s/step - loss: 0.1171 - accuracy: 0.9591 - val_loss: 0.0839 - val_accuracy: 0.9728 - lr: 1.2500e-06
# Epoch 18/35
# 290/290 [==============================] - ETA: 0s - loss: 0.1082 - accuracy: 0.9643
# Epoch 18: val_accuracy did not improve from 0.97276
# 290/290 [==============================] - 995s 3s/step - loss: 0.1082 - accuracy: 0.9643 - val_loss: 0.0795 - val_accuracy: 0.9728 - lr: 1.0000e-06
# Epoch 19/35
# 290/290 [==============================] - ETA: 0s - loss: 0.1142 - accuracy: 0.9622
# Epoch 19: val_accuracy did not improve from 0.97276
# 290/290 [==============================] - 984s 3s/step - loss: 0.1142 - accuracy: 0.9622 - val_loss: 0.0787 - val_accuracy: 0.9728 - lr: 1.0000e-06
# Epoch 20/35
# 290/290 [==============================] - ETA: 0s - loss: 0.1143 - accuracy: 0.9626
# Epoch 20: val_accuracy did not improve from 0.97276
# 290/290 [==============================] - 970s 3s/step - loss: 0.1143 - accuracy: 0.9626 - val_loss: 0.0850 - val_accuracy: 0.9728 - lr: 1.0000e-06
# Epoch 21/35
# 290/290 [==============================] - ETA: 0s - loss: 0.1138 - accuracy: 0.9609
# Epoch 21: val_accuracy did not improve from 0.97276
# Restoring model weights from the end of the best epoch: 14.
# 290/290 [==============================] - 975s 3s/step - loss: 0.1138 - accuracy: 0.9609 - val_loss: 0.0837 - val_accuracy: 0.9708 - lr: 1.0000e-06
# Epoch 21: early stopping

# %% [markdown]
# Test Accuracy

# %%
test_loss, test_accuracy = model.evaluate(test_data / 255.0, test_labels)
print("Test Accuracy:", test_accuracy)
# Out:
# 18/18 [==============================] - 26s 1s/step - loss: 0.0736 - accuracy: 0.9738
# Test Accuracy: 0.9737762212753296

# %%
import cv2, hashlib
import numpy as np

def file_hash(path):
    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (64, 64))
    return hashlib.sha1(img.tobytes()).hexdigest()

train_hashes = set()
test_hashes = set()

train_dir = r"C:\Users\falco\Desktop\emp\BTDataset\Training"
test_dir  = r"C:\Users\falco\Desktop\emp\BTDataset\Testing"

for root, _, files in os.walk(train_dir):
    for f in files:
        train_hashes.add(file_hash(os.path.join(root, f)))

for root, _, files in os.walk(test_dir):
    for f in files:
        test_hashes.add(file_hash(os.path.join(root, f)))

duplicates = train_hashes.intersection(test_hashes)
print(f"Identical images across Train and Test: {len(duplicates)}")
# Out:
# Identical images across Train and Test: 189

# %% [markdown]
# Classification Report

# %%
# Make predictions on the test data
predictions = model.predict(test_data / 255.0)

# Convert predictions and true labels to integer format
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(test_labels, axis=1)

# Calculate the classification report
report = classification_report(true_labels, predicted_labels)

# Calculate the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Print the classification report
print("Classification Report:")
print(report)
# Out:
# 18/18 [==============================] - 29s 1s/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96       132
#            1       0.96      0.93      0.95       134
#            2       1.00      1.00      1.00       160
#            3       0.97      0.99      0.98       146
#
#     accuracy                           0.97       572
#    macro avg       0.97      0.97      0.97       572
# weighted avg       0.97      0.97      0.97       572

# %% [markdown]
# Confusion Matrix

# %%
# Calculate the confusion matrix
cm = confusion_matrix(true_labels, np.round(predicted_labels))

cm
# Out:
# array([[128,   4,   0,   0],
#        [  5, 125,   0,   4],
#        [  0,   0, 160,   0],
#        [  1,   1,   0, 144]], dtype=int64)

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    # print(cm)

    plt.figure(figsize=(6, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=14)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=12)
    plt.yticks(tick_marks, classes, fontsize=12)
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()


cm_plot_labels = ["glioma", "meningioma", "notumor", "pituitary"]

plot_confusion_matrix(cm, cm_plot_labels, title='Confusion Matrix', normalize=True)
# Out:
# Normalized confusion matrix

# %% [markdown]
# ROC-AUC curve

# %%
# Define class names
class_names = ["glioma", "meningioma", "notumor", "pituitary"]

# Make predictions on the test data
predictions = model.predict(test_data / 255.0)

# Get the number of classes
num_classes = test_labels.shape[1]

# Initialize a figure to plot ROC curves
plt.figure(figsize=(6, 6))

# Loop through each class
for class_index in range(num_classes):
    # Compute ROC curve and ROC AUC for the current class
    fpr, tpr, thresholds = roc_curve(test_labels[:, class_index], predictions[:, class_index])
    roc_auc = auc(fpr, tpr)

    # Plot ROC curve for the current class
    plt.plot(fpr, tpr, lw=2, label=f'{class_names[class_index]} (AUC = {roc_auc:.2f})')
# Plot the diagonal line (random chance)plt.plot([0, 1], [0, 1], color='gray', linestyle='--', lw=2)# Set plot propertiesplt.xlim([0.0, 1.0])plt.ylim([0.0, 1.05])plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) - Multiclass')
plt.legend(loc='lower right')

# Display the plot
plt.show()
# Out:
# 18/18 [==============================] - 26s 1s/step

# %% [markdown]
# ## Explainable AI (XAI)

# %%
image_titles = ["glioma", "meningioma", "notumor", "pituitary"]
num_images = len(image_titles)

# Convert one-hot encoded labels to integer labels
test_labels_int = np.argmax(test_labels, axis=1)
# Find the indices of the first image from each class
class_indices = [np.where(test_labels_int == i)[0][0] for i in range(len(image_titles))]

# Create an array to store the images
image_array = []

# Create subplots with 2 rows
num_rows = 2
num_cols = (num_images + 1) // num_rows
fig, ax = plt.subplots(num_rows, num_cols, figsize=(5, 3))

for i, title in enumerate(image_titles):
    row = i // num_cols
    col = i % num_cols
    ax[row, col].set_title(title, fontsize=8)

    # Display the image from test data
    img = test_data[class_indices[i]]
    image_array.append(img)  # Store the image in the array

    ax[row, col].imshow(img)
    ax[row, col].axis('off')

# Remove any empty subplots
for i in range(len(image_titles), num_rows * num_cols):
    row = i // num_cols
    col = i % num_cols
    fig.delaxes(ax[row, col])

plt.tight_layout()
plt.show()

X = base_preprocess(np.array(image_array))

# %% [markdown]
# Random Image

# %%
import random

image_titles = ["glioma", "meningioma", "notumor", "pituitary"]
num_images = len(image_titles)

test_labels_int = np.argmax(test_labels, axis=1)

class_indices = [random.choice(np.where(test_labels_int == i)[0]) for i in range(len(image_titles))]

image_array = []

fig, ax = plt.subplots(1, num_images, figsize=(15, 3))
for i, title in enumerate(image_titles):
    ax[i].set_title(title, fontsize=13)
    ax[i].axis('off')

    img = test_data[class_indices[i]]
    image_array.append(img)
    ax[i].imshow(img)

plt.tight_layout()
plt.show()

X = base_preprocess(np.array(image_array))

# %%
from tf_keras_vis.utils.model_modifiers import ReplaceToLinear

replace2linear = ReplaceToLinear()

def model_modifier_function(cloned_model):
    cloned_model.layers[-1].activation = tf.keras.activations.linear

# %%
from tf_keras_vis.utils.scores import CategoricalScore

score = CategoricalScore([0, 1, 2, 3])


def score_function(output):

    return (output[0][1][2][3])


X_vis = X / 255.0

# %% [markdown]
# Faster Score-Cam

# %%
# %%time
from matplotlib import cm
from tf_keras_vis.scorecam import Scorecam

scorecam = Scorecam(model, model_modifier=replace2linear)

cam = scorecam(
    score,
    X_vis,
    penultimate_layer='top_conv',
    max_N=64,           # 🔽 было None → берёт все 1280, поставь 32–64
    batch_size=8        # 🔽 снижает нагрузку на память
)

# Normalize CAMs for visualization (0–1 range)
cam = (cam - np.min(cam)) / (np.max(cam) - np.min(cam))


num_images = len(image_titles)
num_rows, num_cols = 2, 2  # since you have 4 classes

fig, ax = plt.subplots(num_rows, num_cols, figsize=(7, 6))

for i, title in enumerate(image_titles):
    r, c = divmod(i, num_cols)

    base_img = X_vis[i]

    heatmap = cm.jet(cam[i])[..., :3]

    blended = 0.6 * base_img + 0.4 * heatmap

    ax[r, c].imshow(np.clip(blended, 0, 1))
    ax[r, c].set_title(title, fontsize=10)
    ax[r, c].axis('off')

for i in range(num_images, num_rows * num_cols):
    r, c = divmod(i, num_cols)
    fig.delaxes(ax[r, c])

plt.tight_layout()
plt.show()
# Out:
# CPU times: total: 16.4 s
# Wall time: 14 s
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', "from matplotlib import cm\nfrom tf_keras_vis.scorecam import Scorecam\n\nscorecam = Scorecam(model, model_modifier=replace2linear)\n\ncam = scorecam(\n    score,\n    X_vis,\n    penultimate_layer='top_conv',\n    max_N=64,           # 🔽 было None → берёт все 1280, поставь 32–64\n    batch_size=8        # 🔽 снижает нагрузку на память\n)\n\n# Normalize CAMs for visualization (0–1 range)\ncam = (cam - np.min(cam)) / (np.max(cam) - np.min(cam))\n\n\nnum_images = len(image_titles)\nnum_rows, num_cols = 2, 2  # since you have 4 classes\n\nfig, ax = plt.subplots(num_rows, num_cols, figsize=(7, 6))\n\nfor i, title in enumerate(image_titles):\n    r, c = divmod(i, num_cols)\n\n    base_img = X_vis[i]\n\n    heatmap = cm.jet(cam[i])[..., :3]\n\n    blended = 0.6 * base_img + 0.4 * heatmap\n\n    ax[r, c].imshow(np.clip(blended, 0, 1))\n    ax[r, c].set_title(title, fontsize=10)\n    ax[r, c].axis('off')\n\nfor i in range(num_images, num_rows * num_cols):\n    r, c = divmod(i, num_cols)\n    fig.delaxes(ax[r, c])\n\nplt.tight_layout()\nplt.show()\n")
#
# File c:\Users\falco\Desktop\emp\.venv_gpu\Lib\site-packages\IPython\core\interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\falco\Desktop\emp\.venv_gpu\Lib\site-packages\IPython\core\magics\execution.py:1452, in ExecutionMagics.time(self, line, cell, local_ns)
#    1450 if interrupt_occured:
#    1451     if exit_on_interrupt and captured_exception:
# -> 1452         raise captured_exception
#    1453     return
#    1454 return out
#
# File c:\Users\falco\Desktop\emp\.venv_gpu\Lib\site-packages\IPython\core\magics\execution.py:1416, in ExecutionMagics.time(self, line, cell, local_ns)
#    1414 st = clock2()
#    1415 try:
# -> 1416     exec(code, glob, local_ns)
#    1417     out = None
#    1418     # multi-line %%time case
#
# File <timed exec>:6
#
# File c:\Users\falco\Desktop\emp\.venv_gpu\Lib\site-packages\tf_keras_vis\scorecam.py:159, in Scorecam.__call__(self, score, seed_input, penultimate_layer, seek_penultimate_conv_layer, activation_modifier, batch_size, max_N, training, expand_cam, normalize_cam)
#     153 masked_seed_inputs = [
#     154     np.reshape(seed_input, (-1, ) + seed_input.shape[2:])
#     155     for seed_input in masked_seed_inputs
#     156 ]
#     158 # Predicting masked seed-inputs
# --> 159 preds = self.model.predict(masked_seed_inputs, batch_size=batch_size)
#     160 # (channels * samples, logits) -> (channels, samples, logits)
#     161 preds = (np.reshape(prediction, (channels, nsamples, prediction.shape[-1]))
#     162          for prediction in listify(preds))
#
# File c:\Users\falco\Desktop\emp\.venv_gpu\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\falco\Desktop\emp\.venv_gpu\Lib\site-packages\tensorflow\python\framework\constant_op.py:90, in convert_to_eager_tensor(value, ctx, dtype)
#      70 """Converts the given `value` to an `EagerTensor`.
#      71
#      72 Note that this function could return cached copies of created constants for
#    (...)     84   TypeError: if `dtype` is not compatible with the type of t.
#      85 """
#      86 if isinstance(value, np.ndarray):
#      87   # Make a copy explicitly because the EagerTensor might share the underlying
#      88   # memory with the input array. Without this copy, users will be able to
#      89   # modify the EagerTensor after its creation by changing the input array.
# ---> 90   value = value.copy()
#      91 if isinstance(value, ops.EagerTensor):
#      92   if dtype is not None and value.dtype != dtype:
#
# MemoryError: Unable to allocate 804. MiB for an array with shape (700, 224, 224, 3) and data type float64

# %%
# %%time
from matplotlib import pyplot as plt, cm
from tf_keras_vis.scorecam import Scorecam

scorecam = Scorecam(model, model_modifier=replace2linear)
cam = scorecam(score, X / 255.0, penultimate_layer=-1, max_N=10)
cam = (cam - np.min(cam)) / (np.max(cam) - np.min(cam))

num_images = len(image_titles)
fig, axes = plt.subplots(1, num_images, figsize=(15, 5))

for i, title in enumerate(image_titles):
    heatmap = cm.jet(cam[i])[..., :3]
    base_img = X[i] / 255.0
    blended = 0.6 * base_img + 0.4 * heatmap
    axes[i].set_title(title, fontsize=13)
    axes[i].imshow(np.clip(blended, 0, 1))
    axes[i].axis('off')

plt.tight_layout()
plt.show()
# Out:
# CPU times: total: 7.59 s
# Wall time: 5.74 s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', "from matplotlib import pyplot as plt, cm\nfrom tf_keras_vis.scorecam import Scorecam\n\nscorecam = Scorecam(model, model_modifier=replace2linear)\ncam = scorecam(score, X / 255.0, penultimate_layer=-1, max_N=10)\ncam = (cam - np.min(cam)) / (np.max(cam) - np.min(cam))\n\nnum_images = len(image_titles)\nfig, axes = plt.subplots(1, num_images, figsize=(15, 5))\n\nfor i, title in enumerate(image_titles):\n    heatmap = cm.jet(cam[i])[..., :3]\n    base_img = X[i] / 255.0\n    blended = 0.6 * base_img + 0.4 * heatmap\n    axes[i].set_title(title, fontsize=13)\n    axes[i].imshow(np.clip(blended, 0, 1))\n    axes[i].axis('off')\n\nplt.tight_layout()\nplt.show()\n")
#
# File c:\Users\falco\Desktop\emp\.venv_gpu\Lib\site-packages\IPython\core\interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\falco\Desktop\emp\.venv_gpu\Lib\site-packages\IPython\core\magics\execution.py:1452, in ExecutionMagics.time(self, line, cell, local_ns)
#    1450 if interrupt_occured:
#    1451     if exit_on_interrupt and captured_exception:
# -> 1452         raise captured_exception
#    1453     return
#    1454 return out
#
# File c:\Users\falco\Desktop\emp\.venv_gpu\Lib\site-packages\IPython\core\magics\execution.py:1416, in ExecutionMagics.time(self, line, cell, local_ns)
#    1414 st = clock2()
#    1415 try:
# -> 1416     exec(code, glob, local_ns)
#    1417     out = None
#    1418     # multi-line %%time case
#
# File <timed exec>:5
#
# File c:\Users\falco\Desktop\emp\.venv_gpu\Lib\site-packages\tf_keras_vis\scorecam.py:106, in Scorecam.__call__(self, score, seed_input, penultimate_layer, seek_penultimate_conv_layer, activation_modifier, batch_size, max_N, training, expand_cam, normalize_cam)
#     104     max_N = get_num_of_steps_allowed(max_N)
#     105 else:
# --> 106     raise ValueError(f"max_N must be 1 or more and {penultimate_output.shape[-1]} or less."
#     107                      f" max_N: {max_N}")
#     108 if max_N < penultimate_output.shape[-1]:
#     109     activation_map_std = tf.math.reduce_std(penultimate_output,
#     110                                             axis=tuple(
#     111                                                 range(penultimate_output.ndim)[1:-1]),
#     112                                             keepdims=True)
#
# ValueError: max_N must be 1 or more and 1 or less. max_N: 10
